# %% [markdown]
# # Vision-Language Image-Text Retrieval with CLIP
#
# Prepare the safe gallery, generate CLIP image embeddings, and run natural-language retrieval.
#
# > Educational portfolio use only. Do not use sensitive images or consequential decisions.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()

# %%
from src.dataset_loader import load_gallery
gallery = load_gallery(PROJECT_ROOT / 'web/data/image_gallery.json')
len(gallery)

# %%
# Install requirements-model.txt before enabling model inference.
# from src.clip_model import ClipEncoder
# encoder = ClipEncoder()
