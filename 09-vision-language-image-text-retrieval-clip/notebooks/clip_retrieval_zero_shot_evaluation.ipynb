# %% [markdown]
# # CLIP Retrieval and Zero-Shot Evaluation
#
# Measure Recall@K, similarity distributions, latency, prompt sensitivity, and failure cases without inventing results.
#
# > Educational portfolio use only. Do not use sensitive images or consequential decisions.

# %%
import json
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
queries = json.loads((PROJECT_ROOT / 'data/evaluation_queries.json').read_text())['queries']
len(queries)

# %%
from src.model_evaluation import evaluate_recall
# metrics = evaluate_recall(ranked_ids, relevant_ids)
# metrics
