# %% [markdown]
# # Document Semantic Search with Sentence-BERT
#
# This notebook prepares a public portfolio corpus, generates normalized embeddings, and evaluates retrieval. Do not load confidential or personally identifiable documents.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROJECT_ROOT

# %%
# !python {PROJECT_ROOT / 'scripts/prepare_corpus.py'}
# !python {PROJECT_ROOT / 'scripts/generate_embeddings.py'}
# !python {PROJECT_ROOT / 'scripts/export_browser_data.py'}

# %% [markdown]
# Run `scripts/evaluate_search.py` only after embeddings have been generated. Numeric results should come from actual execution, not placeholders.
