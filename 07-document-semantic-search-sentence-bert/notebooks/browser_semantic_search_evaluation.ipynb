# %% [markdown]
# # Browser Semantic Search Evaluation
#
# Use browser DevTools and the app's latency summary to record first-load, cached-model, query-embedding, and ranking latency. Review relevance manually alongside Recall@K and MRR.

# %%
import json
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
queries = json.loads((root / 'data/processed/evaluation_queries.json').read_text())
queries[:2]

# %% [markdown]
# Record browser, device, cache state, corpus size, top-K, embedding latency, ranking latency, and total latency for each run.
