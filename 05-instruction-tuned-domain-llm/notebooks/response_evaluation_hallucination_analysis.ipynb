# %% [markdown]
# # Response Evaluation & Hallucination Analysis
#
# This notebook compares the base model and trained LoRA adapter using held-out prompts, instruction adherence, BERTScore, relevance, latency, and human review. It intentionally contains no fabricated results.

# %%
from pathlib import Path
import sys
PROJECT_DIR = Path.cwd().resolve()
if PROJECT_DIR.name == "notebooks": PROJECT_DIR = PROJECT_DIR.parent
sys.path.insert(0, str(PROJECT_DIR))

# %%
from src.model_loader import load_model
from src.model_evaluation import evaluate_model
# Base baseline:
# base = load_model(force_base=True)
# evaluate_model(base, PROJECT_DIR / "data/evaluation_prompts.jsonl", PROJECT_DIR / "outputs/base")

# %%
# Adapter evaluation after ADAPTER_MODEL_ID is configured:
# adapter = load_model(force_base=False)
# evaluate_model(adapter, PROJECT_DIR / "data/evaluation_prompts.jsonl", PROJECT_DIR / "outputs/adapter")

# %% [markdown]
# ## Manual review
# Open the generated CSV, verify factual correctness and code behavior, record severity and corrected explanations, and only then copy approved metrics into the README and model card.
