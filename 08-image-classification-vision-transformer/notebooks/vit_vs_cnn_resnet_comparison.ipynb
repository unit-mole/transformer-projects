# %% [markdown]
# # ViT vs CNN / ResNet Comparison
# Use the same dataset split, preprocessing intent, hardware, warm-up and run count. Do not insert unverified values.

# %%
import pandas as pd
comparison = pd.DataFrame([
    {'model':'Vision Transformer','accuracy':None,'macro_f1':None,'parameters':None,'avg_latency_ms':None},
    {'model':'CNN / ResNet baseline','accuracy':None,'macro_f1':None,'parameters':None,'avg_latency_ms':None},
])
comparison
