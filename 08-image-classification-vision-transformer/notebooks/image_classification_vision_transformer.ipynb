# %% [markdown]
# # Vision Transformer Image Classification
# Responsible-use note: use only safe, non-sensitive images and do not use predictions for high-impact decisions.

# %% [markdown]
# ## Experiment checklist
# 1. Load CIFAR-10. 2. Record split and seed. 3. Fine-tune compact DeiT. 4. Evaluate accuracy, macro F1 and confusion matrix. 5. Export ONNX.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
PROJECT_ROOT

# %%
# Add real training code only after selecting compute, epochs and validation protocol.
# The reusable implementation lives in ../src and ../scripts.
